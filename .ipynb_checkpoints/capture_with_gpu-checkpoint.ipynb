# %% [markdown]
# # Playwright활용 스크린캡처 (GPU가속기)
# - Playwright를 이용하여 headless 상태에서 screenshot
# - GPU 가속기 설정으로, 스크린캡처 등 속도 가속화
#
# # 설정
# ```
# pip install -r requirements.txt
# playwright install
# ```
#
# - playwright install이 디펜던시로 설치가 되지 않는 경우,
# `playwrite install-deps` 를 사용하여 설치

# %%
# !pip install playwright

# %%
# !playwright install
# Out:
# Playwright Host validation warning:
# ╔══════════════════════════════════════════════════════╗
# ║ Host system is missing dependencies to run browsers. ║
# ║ Please install them with the following command:      ║
# ║                                                      ║
# ║     sudo playwright install-deps                     ║
# ║                                                      ║
# ║ Alternatively, use apt:                              ║
# ║     sudo apt-get install libglib2.0-0\               ║
# ║         libnspr4\                                    ║
# ║         libnss3\                                     ║
# ║         libdbus-1-3\                                 ║
# ║         libatk1.0-0\                                 ║
# ║         libatk-bridge2.0-0\                          ║
# ║         libcups2\                                    ║
# ║         libxcb1\                                     ║
# ║         libxkbcommon0\                               ║
# ║         libatspi2.0-0\                               ║
# ║         libx11-6\                                    ║
# ║         libxcomposite1\                              ║
# ║         libxdamage1\                                 ║
# ║         libxext6\                                    ║
# ║         libxfixes3\                                  ║
# ║         libxrandr2\                                  ║
# ║         libgbm1\                                     ║
# ║         libcairo2\                                   ║
# ║         libpango-1.0-0\                              ║
# ║         libasound2                                   ║
# ║                                                      ║
# ║ <3 Playwright Team                                   ║
# ╚══════════════════════════════════════════════════════╝
#     at validateDependenciesLinux (/opt/conda/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/dependencies.js:269:9)
#     at process.processTicksAndRejections (node:internal/process/task_queues:105:5)
#     at async Registry._validateHostRequirements (/opt/conda/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/index.js:927:14)
#     at async Registry._validateHostRequirementsForExecutableIfNeeded (/opt/conda/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/index.js:1049:7)
#     at async Registry.validateHostRequirementsForExecutablesIfNeeded (/opt/conda/lib/python3.11/site-packages/playwright/driver/package/lib/server/registry/index.js:1038:7)
#     at async t.<anonymous> (/opt/conda/lib/python3.11/site-packages/playwright/driver/package/lib/cli/program.js:217:7)

# %%
# !playwright install-deps
# Out:
# Installing dependencies...
# Switching to root user to install dependencies...
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1581 B]
# Get:2 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1801 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1254 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4587 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [3040 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [47.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [55.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1562 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3351 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [4741 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [83.2 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [35.2 kB]
# Fetched 20.9 MB in 2s (9372 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libicu70 is already the newest version (70.1-2).
# libicu70 set to manually installed.
# libatomic1 is already the newest version (12.3.0-1ubuntu1~22.04).
# libatomic1 set to manually installed.
# The following additional packages will be installed:
#   adwaita-icon-theme dbus dbus-user-session dconf-gsettings-backend
#   dconf-service dictionaries-common emacsen-common fontconfig
#   fontconfig-config glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gtk-update-icon-cache
#   hicolor-icon-theme humanity-icon-theme hunspell-en-us iso-codes libaa1
#   libabsl20210324 libaom3 libapparmor1 libargon2-1 libasound2-data libaspell15
#   libass9 libasyncns0 libatk1.0-data libavahi-client3 libavahi-common-data
#   libavahi-common3 libavc1394-0 libavcodec58 libavdevice58 libavfilter7
#   libavformat58 libavutil56 libblas3 libbluray2 libbs2b0 libcaca0
#   libcairo-script-interpreter2 libcap2-bin libcdio-cdda2 libcdio-paranoia2
#   libcdio19 libcdparanoia0 libchromaprint1 libcodec2-1.0 libcolord2
#   libcryptsetup12 libdatrie1 libdav1d5 libdc1394-25 libdca0 libdconf1
#   libde265-0 libdecor-0-0 libdeflate0 libdevmapper1.02.1 libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdv4 libdvdnav4
#   libdvdread8 libdw1 libegl-mesa0 libelf1 libfaad2 libflac8 libflite1
#   libfluidsynth3 libfontenc1 libfreeaptx0 libfribidi0 libgav1-0
#   libgdk-pixbuf2.0-common libgfortran5 libgl1 libgl1-mesa-dri libglapi-mesa
#   libglvnd0 libglx-mesa0 libgme0 libgpm2 libgraphene-1.0-0 libgraphite2-3
#   libgsm1 libgssdp-1.2-0 libgstreamer-plugins-bad1.0-0
#   libgstreamer-plugins-good1.0-0 libgtk-3-common libgtk-4-common
#   libgupnp-1.2-1 libgupnp-igd-1.0-4 libhunspell-1.7-0 libice6 libiec61883-0
#   libilmbase25 libinstpatch-1.0-2 libip4tc2 libjack-jackd2-0 libjbig0 libjpeg8
#   libjson-glib-1.0-0 libjson-glib-1.0-common libkate1 libkmod2 liblapack3
#   libldacbt-enc2 liblilv-0-0 libllvm15 libltc11 liblzo2-2 libmfx1
#   libmjpegutils-2.1-0 libmodplug1 libmp3lame0 libmpcdec6 libmpeg2encpp-2.1-0
#   libmpg123-0 libmplex2-2.1-0 libmysofa1 libnice10 libnorm1 libnuma1 libogg0
#   libopenal-data libopenal1 libopenexr25 libopenh264-6 libopenmpt0
#   libopenni2-0 liborc-0.4-0 libpam-systemd libpangoft2-1.0-0 libpciaccess0
#   libpgm-5.3-0 libpixman-1-0 libpocketsphinx3 libpostproc55 libpulse0
#   libqrencode4 librabbitmq4 libraw1394-11 librsvg2-2 librubberband2
#   libsamplerate0 libsbc1 libsdl2-2.0-0 libsecret-common libsensors-config
#   libsensors5 libserd-0-0 libshine3 libshout3 libslang2 libsm6 libsnappy1v5
#   libsndfile1 libsndio7.0 libsodium23 libsord-0-0 libsoundtouch1
#   libsoup-3.0-common libsoup2.4-1 libsoup2.4-common libsoxr0 libspandsp2
#   libspeex1 libsphinxbase3 libsratom-0-0 libsrt1.4-gnutls libsrtp2-1
#   libssh-gcrypt-4 libswresample3 libswscale5 libsystemd0 libtag1v5
#   libtag1v5-vanilla libtext-iconv-perl libthai-data libthai0 libtheora0
#   libtiff5 libtwolame0 libudfread0 libunwind8 libusb-1.0-0 libv4l-0
#   libv4lconvert0 libva-drm2 libva-x11-2 libva2 libvdpau1 libvidstab1.1
#   libvisual-0.4-0 libvo-aacenc0 libvo-amrwbenc0 libvorbis0a libvorbisenc2
#   libvorbisfile3 libvpx7 libwavpack1 libwayland-cursor0 libwebp7 libwebpmux3
#   libwebrtc-audio-processing1 libwildmidi2 libx11-data libx265-199 libxau6
#   libxaw7 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-randr0 libxcb-render0 libxcb-shape0 libxcb-sync1 libxcb-xfixes0
#   libxdmcp6 libxfont2 libxinerama1 libxkbfile1 libxmu6 libxmuu1 libxpm4
#   libxshmfence1 libxss1 libxt6 libxv1 libxvidcore4 libxxf86vm1 libyuv0
#   libzbar0 libzimg2 libzmq5 libzvbi-common libzvbi0 libzxingcore1
#   ocl-icd-libopencl1 session-migration shared-mime-info systemd systemd-sysv
#   timgm6mb-soundfont ubuntu-mono ucf x11-common x11-xkb-utils xauth
#   xfonts-encodings xfonts-utils xkb-data xserver-common
# Suggested packages:
#   ispell | aspell | hunspell wordlist ffmpeg-doc frei0r-plugins gvfs hunspell
#   openoffice.org-hunspell | openoffice.org-core isoquery libasound2-plugins
#   alsa-utils aspell libcuda1 libnvcuvid1 libnvidia-encode1 libbluray-bdj
#   colord cups-common libdv-bin oss-compat libdvdcss2 libenchant-2-voikko gpm
#   libvisual-0.4-plugins gstreamer1.0-tools libgtk-4-media-gstreamer
#   | libgtk-4-media-ffmpeg jackd2 liblcms2-utils gnome-shell
#   | notification-daemon libportaudio2 opus-tools pciutils pulseaudio
#   libraw1394-doc librsvg2-bin xdg-utils lm-sensors serdi sndiod sordi speex
#   libwildmidi-config opencl-icd systemd-container libtss2-esys-3.0.2-0
#   libtss2-mu0 libtss2-rc0 policykit-1 fluid-soundfont-gm
# Recommended packages:
#   librsvg2-common fonts-ipafont-mincho fonts-tlwg-loma gstreamer1.0-x
#   alsa-ucm-conf alsa-topology-conf aspell-en | aspell-dictionary
#   | aspell6a-dictionary at-spi2-core libaacs0 libpam-cap
#   libdecor-0-plugin-1-cairo | libdecor-0-plugin-1 dmsetup enchant-2
#   libgdk-pixbuf2.0-bin libgl1-amber-dri libglib2.0-data xdg-user-dirs
#   gstreamer1.0-gl libgtk-3-bin libgtk-4-bin pocketsphinx-en-us va-driver-all
#   | va-driver vdpau-driver-all | vdpau-driver libmagickcore-6.q16-6-extra
#   networkd-dispatcher systemd-timesyncd | time-daemon libnss-systemd
#   xfonts-base
# The following NEW packages will be installed:
#   adwaita-icon-theme dbus dbus-user-session dconf-gsettings-backend
#   dconf-service dictionaries-common emacsen-common ffmpeg fontconfig
#   fontconfig-config fonts-freefont-ttf fonts-ipafont-gothic fonts-liberation
#   fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-unifont fonts-wqy-zenhei
#   glib-networking glib-networking-common glib-networking-services
#   gsettings-desktop-schemas gstreamer1.0-libav gstreamer1.0-plugins-bad
#   gstreamer1.0-plugins-base gstreamer1.0-plugins-good gtk-update-icon-cache
#   hicolor-icon-theme humanity-icon-theme hunspell-en-us iso-codes libaa1
#   libabsl20210324 libaom3 libapparmor1 libargon2-1 libasound2 libasound2-data
#   libaspell15 libass9 libasyncns0 libatk-bridge2.0-0 libatk1.0-0
#   libatk1.0-data libatspi2.0-0 libavahi-client3 libavahi-common-data
#   libavahi-common3 libavc1394-0 libavcodec58 libavdevice58 libavfilter7
#   libavformat58 libavif13 libavutil56 libblas3 libbluray2 libbs2b0 libcaca0
#   libcairo-gobject2 libcairo-script-interpreter2 libcairo2 libcap2-bin
#   libcdio-cdda2 libcdio-paranoia2 libcdio19 libcdparanoia0 libchromaprint1
#   libcodec2-1.0 libcolord2 libcryptsetup12 libcups2 libdatrie1 libdav1d5
#   libdbus-1-3 libdbus-glib-1-2 libdc1394-25 libdca0 libdconf1 libde265-0
#   libdecor-0-0 libdeflate0 libdevmapper1.02.1 libdrm-amdgpu1 libdrm-common
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libdv4 libdvdnav4
#   libdvdread8 libdw1 libegl-mesa0 libegl1 libelf1 libenchant-2-2 libepoxy0
#   libevdev2 libevent-2.1-7 libfaad2 libffi7 libflac8 libflite1 libfluidsynth3
#   libfontconfig1 libfontenc1 libfreeaptx0 libfreetype6 libfribidi0 libgav1-0
#   libgbm1 libgdk-pixbuf-2.0-0 libgdk-pixbuf2.0-common libgfortran5 libgl1
#   libgl1-mesa-dri libglapi-mesa libgles2 libglib2.0-0 libglvnd0 libglx-mesa0
#   libglx0 libgme0 libgpm2 libgraphene-1.0-0 libgraphite2-3 libgsm1
#   libgssdp-1.2-0 libgstreamer-gl1.0-0 libgstreamer-plugins-bad1.0-0
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgtk-3-0 libgtk-3-common libgtk-4-1 libgtk-4-common
#   libgudev-1.0-0 libgupnp-1.2-1 libgupnp-igd-1.0-4 libharfbuzz-icu0
#   libharfbuzz0b libhunspell-1.7-0 libhyphen0 libice6 libiec61883-0
#   libilmbase25 libinstpatch-1.0-2 libip4tc2 libjack-jackd2-0 libjbig0
#   libjpeg-turbo8 libjpeg8 libjson-glib-1.0-0 libjson-glib-1.0-common libkate1
#   libkmod2 liblapack3 liblcms2-2 libldacbt-enc2 liblilv-0-0 libllvm15 libltc11
#   liblzo2-2 libmanette-0.2-0 libmfx1 libmjpegutils-2.1-0 libmodplug1
#   libmp3lame0 libmpcdec6 libmpeg2encpp-2.1-0 libmpg123-0 libmplex2-2.1-0
#   libmysofa1 libnice10 libnorm1 libnotify4 libnspr4 libnss3 libnuma1 libogg0
#   libopenal-data libopenal1 libopenexr25 libopengl0 libopenh264-6 libopenjp2-7
#   libopenmpt0 libopenni2-0 libopus0 liborc-0.4-0 libpam-systemd libpango-1.0-0
#   libpangocairo-1.0-0 libpangoft2-1.0-0 libpciaccess0 libpgm-5.3-0
#   libpixman-1-0 libpng16-16 libpocketsphinx3 libpostproc55 libproxy1v5
#   libpulse0 libqrencode4 librabbitmq4 libraw1394-11 librsvg2-2 librubberband2
#   libsamplerate0 libsbc1 libsdl2-2.0-0 libsecret-1-0 libsecret-common
#   libsensors-config libsensors5 libserd-0-0 libshine3 libshout3 libslang2
#   libsm6 libsnappy1v5 libsndfile1 libsndio7.0 libsodium23 libsord-0-0
#   libsoundtouch1 libsoup-3.0-0 libsoup-3.0-common libsoup2.4-1
#   libsoup2.4-common libsoxr0 libspandsp2 libspeex1 libsphinxbase3
#   libsratom-0-0 libsrt1.4-gnutls libsrtp2-1 libssh-gcrypt-4 libswresample3
#   libswscale5 libtag1v5 libtag1v5-vanilla libtext-iconv-perl libthai-data
#   libthai0 libtheora0 libtiff5 libtwolame0 libudfread0 libunwind8 libusb-1.0-0
#   libv4l-0 libv4lconvert0 libva-drm2 libva-x11-2 libva2 libvdpau1
#   libvidstab1.1 libvisual-0.4-0 libvo-aacenc0 libvo-amrwbenc0 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx7 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1 libwayland-server0 libwebp7 libwebpdemux2
#   libwebpmux3 libwebrtc-audio-processing1 libwildmidi2 libwoff1 libx11-6
#   libx11-data libx11-xcb1 libx264-163 libx265-199 libxau6 libxaw7
#   libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0 libxcb-randr0
#   libxcb-render0 libxcb-shape0 libxcb-shm0 libxcb-sync1 libxcb-xfixes0 libxcb1
#   libxcomposite1 libxcursor1 libxdamage1 libxdmcp6 libxext6 libxfixes3
#   libxfont2 libxi6 libxinerama1 libxkbcommon0 libxkbfile1 libxmu6 libxmuu1
#   libxpm4 libxrandr2 libxrender1 libxshmfence1 libxslt1.1 libxss1 libxt6
#   libxtst6 libxv1 libxvidcore4 libxxf86vm1 libyuv0 libzbar0 libzimg2 libzmq5
#   libzvbi-common libzvbi0 libzxingcore1 ocl-icd-libopencl1 session-migration
#   shared-mime-info systemd systemd-sysv timgm6mb-soundfont ubuntu-mono ucf
#   x11-common x11-xkb-utils xauth xfonts-cyrillic xfonts-encodings
#   xfonts-scalable xfonts-utils xkb-data xserver-common xvfb
# The following packages will be upgraded:
#   libsystemd0 libxml2
# 2 upgraded, 343 newly installed, 0 to remove and 52 not upgraded.
# Need to get 181 MB of archives.
# After this operation, 605 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsystemd0 amd64 249.11-0ubuntu3.16 [317 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libapparmor1 amd64 3.0.4-2ubuntu2.4 [39.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libargon2-1 amd64 0~20171227-0.3 [19.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdevmapper1.02.1 amd64 2:1.02.175-2.1ubuntu5 [139 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcryptsetup12 amd64 2:2.4.3-1ubuntu1.3 [211 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libip4tc2 amd64 1.8.7-1ubuntu5.2 [19.9 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libkmod2 amd64 29-1ubuntu1 [48.0 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd amd64 249.11-0ubuntu3.16 [4581 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 systemd-sysv amd64 249.11-0ubuntu3.16 [10.5 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3513 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdbus-1-3 amd64 1.12.20-2ubuntu4.1 [189 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dbus amd64 1.12.20-2ubuntu4.1 [158 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 iso-codes all 4.9.0-1 [3459 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcap2-bin amd64 1:2.44-1ubuntu0.22.04.2 [26.0 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libelf1 amd64 0.186-1ubuntu0.1 [51.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfribidi0 amd64 1.0.8-2ubuntu3.1 [26.1 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglib2.0-0 amd64 2.72.4-0ubuntu2.5 [1466 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpam-systemd amd64 249.11-0ubuntu3.16 [203 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libslang2 amd64 2.3.2-5build4 [468 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxml2 amd64 2.9.13+dfsg-1ubuntu0.7 [763 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 shared-mime-info amd64 2.1-2 [454 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 ucf all 3.0043 [56.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 xkb-data all 2.33-1 [394 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-common all 2.4.113-2~ubuntu0.22.04.1 [5450 B]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm2 amd64 2.4.113-2~ubuntu0.22.04.1 [38.1 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnuma1 amd64 2.0.14-3ubuntu2 [22.5 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpng16-16 amd64 1.6.37-3build5 [191 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libusb-1.0-0 amd64 2:1.0.25-1ubuntu2 [52.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxau6 amd64 1:1.0.9-1build5 [7634 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxdmcp6 amd64 1:1.1.3-0ubuntu5 [10.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb1 amd64 1.14-3ubuntu3 [49.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-data all 2:1.7.5-1ubuntu0.3 [120 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-6 amd64 2:1.7.5-1ubuntu0.3 [667 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxext6 amd64 2:1.3.4-1build1 [31.8 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmuu1 amd64 2:1.1.3-3 [10.2 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 xauth amd64 1:1.1-1build2 [27.5 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 hicolor-icon-theme all 0.17-2 [9976 B]
# Get:39 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf2.0-common all 2.42.8+dfsg-1ubuntu0.3 [5630 B]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjpeg-turbo8 amd64 2.1.2-0ubuntu1 [134 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjpeg8 amd64 8c-2ubuntu10 [2264 B]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdeflate0 amd64 1.10-2 [70.9 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libjbig0 amd64 2.1-3.1ubuntu0.22.04.1 [29.2 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebp7 amd64 1.2.2-2ubuntu0.22.04.2 [206 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtiff5 amd64 4.3.0-6ubuntu0.10 [185 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgdk-pixbuf-2.0-0 amd64 2.42.8+dfsg-1ubuntu0.3 [148 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gtk-update-icon-cache amd64 3.24.33-1ubuntu2.2 [31.4 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 humanity-icon-theme all 0.6.16 [1282 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 ubuntu-mono all 20.10-0ubuntu2 [153 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/main amd64 adwaita-icon-theme all 41.0-1ubuntu1 [3444 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dbus-user-session amd64 1.12.20-2ubuntu4.1 [9442 B]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdconf1 amd64 0.40.0-3 [40.5 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/main amd64 dconf-service amd64 0.40.0-3 [28.5 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/main amd64 dconf-gsettings-backend amd64 0.40.0-3 [22.8 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 emacsen-common all 3.0.4 [14.9 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libaom3 amd64 3.3.0-1ubuntu0.1 [1748 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva2 amd64 2.14.0-1 [65.0 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmfx1 amd64 22.3.0-1 [3105 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva-drm2 amd64 2.14.0-1 [7502 B]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes3 amd64 1:6.0.0-1 [11.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva-x11-2 amd64 2.14.0-1 [12.6 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvdpau1 amd64 1.4-3build2 [27.0 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ocl-icd-libopencl1 amd64 2.2.14-3 [39.1 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavutil56 amd64 7:4.4.2-0ubuntu0.22.04.1 [290 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libfreetype6 amd64 2.11.1+dfsg-1ubuntu0.3 [388 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation all 1:1.07.4-11 [822 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2388 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 fontconfig-config all 2.13.1-4.2ubuntu5 [29.1 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontconfig1 amd64 2.13.1-4.2ubuntu5 [131 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpixman-1-0 amd64 0.40.0-1ubuntu0.22.04.1 [264 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render0 amd64 1.14-3ubuntu3 [16.4 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-shm0 amd64 1.14-3ubuntu3 [5780 B]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrender1 amd64 1:0.9.10-1build4 [19.7 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo2 amd64 1.16.0-5ubuntu2 [628 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcodec2-1.0 amd64 1.0.1-3 [8435 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdav1d5 amd64 0.9.2-1 [463 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsm1 amd64 1.0.19-1 [27.7 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmp3lame0 amd64 3.100-3build2 [141 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libopenjp2-7 amd64 2.4.0-6ubuntu0.3 [158 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopus0 amd64 1.3.1-0.1build2 [203 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-gobject2 amd64 1.16.0-5ubuntu2 [19.4 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 fontconfig amd64 2.13.1-4.2ubuntu5 [177 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphite2-3 amd64 1.3.14-1build2 [71.3 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz0b amd64 2.7.4-1ubuntu3.2 [353 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libthai-data all 0.1.29-1build1 [162 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdatrie1 amd64 0.2.13-2 [19.9 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 libthai0 amd64 0.1.29-1build1 [19.2 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpango-1.0-0 amd64 1.50.6+ds-2ubuntu1 [230 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangoft2-1.0-0 amd64 1.50.6+ds-2ubuntu1 [54.0 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpangocairo-1.0-0 amd64 1.50.6+ds-2ubuntu1 [39.8 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 librsvg2-2 amd64 2.52.5+dfsg-3ubuntu0.2 [2974 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libshine3 amd64 3.1.1-2 [23.2 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsnappy1v5 amd64 1.1.8-1build3 [17.5 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 libspeex1 amd64 1.2~rc1.2-1.1ubuntu3 [57.9 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsoxr0 amd64 0.1.3-4build2 [79.8 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswresample3 amd64 7:4.4.2-0ubuntu0.22.04.1 [62.2 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 libogg0 amd64 1.3.5-0ubuntu3 [22.9 kB]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15ubuntu4 [209 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtwolame0 amd64 0.4.0-2build2 [52.5 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbis0a amd64 1.3.7-1build2 [99.2 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisenc2 amd64 1.3.7-1build2 [82.6 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libvpx7 amd64 1.11.0-2ubuntu2.4 [1078 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpmux3 amd64 1.2.2-2ubuntu0.22.04.2 [20.5 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libx264-163 amd64 2:0.163.3060+git5db6aa6-2build1 [591 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libx265-199 amd64 3.5-2 [1170 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxvidcore4 amd64 2:1.3.7-1 [201 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi-common all 0.2.35-19 [35.5 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi0 amd64 0.2.35-19 [262 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavcodec58 amd64 7:4.4.2-0ubuntu0.22.04.1 [5567 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasound2-data all 1.2.6.1-1ubuntu1 [19.1 kB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasound2 amd64 1.2.6.1-1ubuntu1 [390 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraw1394-11 amd64 2.1.2-2build2 [27.0 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy/main amd64 libavc1394-0 amd64 0.5.4-5build2 [17.0 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libass9 amd64 1:0.15.2-1 [97.5 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libudfread0 amd64 1.1.2-1 [16.2 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbluray2 amd64 1:1.3.1-1 [159 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libchromaprint1 amd64 1.5.1-2 [28.4 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgme0 amd64 0.6.3-2 [127 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libmpg123-0 amd64 1.29.3-1ubuntu0.1 [172 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisfile3 amd64 1.3.7-1build2 [17.1 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenmpt0 amd64 0.6.1-1 [592 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy/main amd64 librabbitmq4 amd64 0.10.0-1ubuntu2 [39.3 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrt1.4-gnutls amd64 1.4.4-4 [309 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssh-gcrypt-4 amd64 0.9.6-2ubuntu0.22.04.3 [223 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnorm1 amd64 1.5.9+dfsg-2 [221 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpgm-5.3-0 amd64 5.3.128~dfsg-2 [161 kB]
# Get:128 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsodium23 amd64 1.0.18-1build2 [164 kB]
# Get:129 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzmq5 amd64 4.3.4-2 [256 kB]
# Get:130 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavformat58 amd64 7:4.4.2-0ubuntu0.22.04.1 [1103 kB]
# Get:131 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2build1 [10.2 kB]
# Get:132 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libflite1 amd64 2.2-3 [13.7 MB]
# Get:133 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libserd-0-0 amd64 0.30.10-2 [40.8 kB]
# Get:134 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsord-0-0 amd64 0.16.8-2 [21.2 kB]
# Get:135 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsratom-0-0 amd64 0.6.8-1 [17.0 kB]
# Get:136 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblilv-0-0 amd64 0.24.12-2 [42.8 kB]
# Get:137 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmysofa1 amd64 1.2.1~dfsg0-1 [1157 kB]
# Get:138 http://archive.ubuntu.com/ubuntu jammy/main amd64 libblas3 amd64 3.10.0-2ubuntu1 [228 kB]
# Get:139 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgfortran5 amd64 12.3.0-1ubuntu1~22.04 [879 kB]
# Get:140 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblapack3 amd64 3.10.0-2ubuntu1 [2504 kB]
# Get:141 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasyncns0 amd64 0.8-6build2 [12.8 kB]
# Get:142 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libflac8 amd64 1.3.3-2ubuntu0.2 [111 kB]
# Get:143 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsndfile1 amd64 1.0.31-2ubuntu0.2 [196 kB]
# Get:144 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-xcb1 amd64 2:1.7.5-1ubuntu0.3 [7802 B]
# Get:145 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse0 amd64 1:15.99.1+dfsg1-1ubuntu2.2 [298 kB]
# Get:146 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsphinxbase3 amd64 0.8+5prealpha+1-13build1 [126 kB]
# Get:147 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpocketsphinx3 amd64 0.8.0+real5prealpha+1-14ubuntu1 [132 kB]
# Get:148 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpostproc55 amd64 7:4.4.2-0ubuntu0.22.04.1 [60.1 kB]
# Get:149 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsamplerate0 amd64 0.2.2-1build1 [1359 kB]
# Get:150 http://archive.ubuntu.com/ubuntu jammy/universe amd64 librubberband2 amd64 2.0.0-2 [90.0 kB]
# Get:151 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswscale5 amd64 7:4.4.2-0ubuntu0.22.04.1 [180 kB]
# Get:152 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvidstab1.1 amd64 1.1.0-2 [35.0 kB]
# Get:153 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzimg2 amd64 3.0.3+ds1-1 [241 kB]
# Get:154 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavfilter7 amd64 7:4.4.2-0ubuntu0.22.04.1 [1496 kB]
# Get:155 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcaca0 amd64 0.99.beta19-2.2ubuntu4 [224 kB]
# Get:156 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcdio19 amd64 2.1.0-3ubuntu0.2 [63.6 kB]
# Get:157 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-cdda2 amd64 10.2+2.0.0-1build3 [16.7 kB]
# Get:158 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-paranoia2 amd64 10.2+2.0.0-1build3 [15.9 kB]
# Get:159 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdc1394-25 amd64 2.2.6-4 [88.8 kB]
# Get:160 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd0 amd64 1.4.0-1 [73.6 kB]
# Get:161 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglapi-mesa amd64 23.2.1-1ubuntu3.1~22.04.3 [35.4 kB]
# Get:162 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-dri2-0 amd64 1.14-3ubuntu3 [7206 B]
# Get:163 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-dri3-0 amd64 1.14-3ubuntu3 [6968 B]
# Get:164 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-glx0 amd64 1.14-3ubuntu3 [25.9 kB]
# Get:165 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-present0 amd64 1.14-3ubuntu3 [5734 B]
# Get:166 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-randr0 amd64 1.14-3ubuntu3 [18.3 kB]
# Get:167 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-sync1 amd64 1.14-3ubuntu3 [9416 B]
# Get:168 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xfixes0 amd64 1.14-3ubuntu3 [9996 B]
# Get:169 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxshmfence1 amd64 1.3-1build4 [5394 B]
# Get:170 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86vm1 amd64 1:1.1.4-1build3 [10.4 kB]
# Get:171 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-amdgpu1 amd64 2.4.113-2~ubuntu0.22.04.1 [19.9 kB]
# Get:172 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess0 amd64 0.16-3 [19.1 kB]
# Get:173 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-intel1 amd64 2.4.113-2~ubuntu0.22.04.1 [66.7 kB]
# Get:174 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-nouveau2 amd64 2.4.113-2~ubuntu0.22.04.1 [17.5 kB]
# Get:175 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-radeon1 amd64 2.4.113-2~ubuntu0.22.04.1 [21.6 kB]
# Get:176 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libllvm15 amd64 1:15.0.7-0ubuntu0.22.04.3 [25.4 MB]
# Get:177 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsensors-config all 1:3.6.0-7ubuntu1 [5274 B]
# Get:178 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsensors5 amd64 1:3.6.0-7ubuntu1 [26.3 kB]
# Get:179 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dri amd64 23.2.1-1ubuntu3.1~22.04.3 [8860 kB]
# Get:180 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglx-mesa0 amd64 23.2.1-1ubuntu3.1~22.04.3 [158 kB]
# Get:181 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx0 amd64 1.4.0-1 [41.0 kB]
# Get:182 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl1 amd64 1.4.0-1 [110 kB]
# Get:183 http://archive.ubuntu.com/ubuntu jammy/main amd64 libiec61883-0 amd64 1.2.0-4build3 [25.9 kB]
# Get:184 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjack-jackd2-0 amd64 1.9.20~dfsg-1 [293 kB]
# Get:185 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal-data all 1:1.19.1-2build3 [164 kB]
# Get:186 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsndio7.0 amd64 1.8.1-1.1 [29.3 kB]
# Get:187 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal1 amd64 1:1.19.1-2build3 [535 kB]
# Get:188 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-client0 amd64 1.20.0-1ubuntu0.1 [25.9 kB]
# Get:189 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-0 amd64 0.1.0-3build1 [15.1 kB]
# Get:190 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-server0 amd64 1.20.0-1ubuntu0.1 [34.3 kB]
# Get:191 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgbm1 amd64 23.2.1-1ubuntu3.1~22.04.3 [33.5 kB]
# Get:192 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-cursor0 amd64 1.20.0-1ubuntu0.1 [10.7 kB]
# Get:193 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-egl1 amd64 1.20.0-1ubuntu0.1 [5582 B]
# Get:194 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor1 amd64 1:1.2.0-2build4 [20.9 kB]
# Get:195 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi6 amd64 2:1.8-1build1 [32.6 kB]
# Get:196 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama1 amd64 2:1.1.4-3 [7382 B]
# Get:197 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon0 amd64 1.4.0-1 [125 kB]
# Get:198 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr2 amd64 2:1.5.2-1build1 [20.4 kB]
# Get:199 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-common all 1:7.7+23ubuntu2 [23.4 kB]
# Get:200 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxss1 amd64 1:1.2.3-1build2 [8476 B]
# Get:201 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsdl2-2.0-0 amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [582 kB]
# Get:202 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-shape0 amd64 1.14-3ubuntu3 [6158 B]
# Get:203 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxv1 amd64 2:1.0.11-1build2 [11.2 kB]
# Get:204 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavdevice58 amd64 7:4.4.2-0ubuntu0.22.04.1 [87.5 kB]
# Get:205 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 ffmpeg amd64 7:4.4.2-0ubuntu0.22.04.1 [1696 kB]
# Get:206 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:207 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:208 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3551 kB]
# Get:209 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7472 kB]
# Get:210 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:211 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3718 B]
# Get:212 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9982 B]
# Get:213 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9774 B]
# Get:214 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:215 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:216 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdw1 amd64 0.186-1ubuntu0.1 [251 kB]
# Get:217 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libunwind8 amd64 1.3.2-2build2.1 [54.5 kB]
# Get:218 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer1.0-0 amd64 1.20.3-0ubuntu1.1 [984 kB]
# Get:219 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 liborc-0.4-0 amd64 1:0.4.32-2ubuntu0.1 [228 kB]
# Get:220 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.4 [848 kB]
# Get:221 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-libav amd64 1.20.3-0ubuntu1 [103 kB]
# Get:222 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:223 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:224 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.4 [712 kB]
# Get:225 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgpm2 amd64 1.20.7-10build1 [15.3 kB]
# Get:226 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaa1 amd64 1.4p5-50build1 [51.9 kB]
# Get:227 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdv4 amd64 1.0.0-14build1 [61.9 kB]
# Get:228 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.20.3-0ubuntu1.3 [30.1 kB]
# Get:229 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:230 http://archive.ubuntu.com/ubuntu jammy/main amd64 libshout3 amd64 2.4.5-1build3 [54.5 kB]
# Get:231 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-3ubuntu3 [304 kB]
# Get:232 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-3ubuntu3 [11.5 kB]
# Get:233 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4lconvert0 amd64 1.22.1-2build1 [82.4 kB]
# Get:234 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4l-0 amd64 1.22.1-2build1 [44.9 kB]
# Get:235 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwavpack1 amd64 5.4.0-1build2 [83.7 kB]
# Get:236 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxdamage1 amd64 1:1.1.5-2build2 [7154 B]
# Get:237 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-common all 2.74.2-3ubuntu0.5 [4660 B]
# Get:238 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsoup2.4-1 amd64 2.74.2-3ubuntu0.5 [287 kB]
# Get:239 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-good amd64 1.20.3-0ubuntu1.3 [2010 kB]
# Get:240 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:241 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libabsl20210324 amd64 0~20210324.2-2ubuntu0.2 [386 kB]
# Get:242 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaspell15 amd64 0.60.8-4build1 [325 kB]
# Get:243 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2824 B]
# Get:244 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:245 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:246 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:247 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-common-data amd64 0.8-5ubuntu5.2 [23.8 kB]
# Get:248 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-common3 amd64 0.8-5ubuntu5.2 [23.9 kB]
# Get:249 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-client3 amd64 0.8-5ubuntu5.2 [28.0 kB]
# Get:250 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgav1-0 amd64 0.17.0-1build1 [336 kB]
# Get:251 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libyuv0 amd64 0.0~git20220104.b91df1a-2 [154 kB]
# Get:252 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libavif13 amd64 0.9.3-3 [69.5 kB]
# Get:253 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblzo2-2 amd64 2.10-2build3 [53.7 kB]
# Get:254 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcairo-script-interpreter2 amd64 1.16.0-5ubuntu2 [62.0 kB]
# Get:255 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblcms2-2 amd64 2.12~rc1-2build2 [159 kB]
# Get:256 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolord2 amd64 1.4.6-1 [155 kB]
# Get:257 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcups2 amd64 2.4.1op1-1ubuntu4.11 [263 kB]
# Get:258 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbus-glib-1-2 amd64 0.112-2build1 [65.4 kB]
# Get:259 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libde265-0 amd64 1.0.8-1ubuntu0.3 [290 kB]
# Get:260 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdread8 amd64 6.1.2-1 [55.7 kB]
# Get:261 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdnav4 amd64 6.1.1-1 [39.3 kB]
# Get:262 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl-mesa0 amd64 23.2.1-1ubuntu3.1~22.04.3 [118 kB]
# Get:263 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:264 http://archive.ubuntu.com/ubuntu jammy/main amd64 libenchant-2-2 amd64 2.3.2-1ubuntu2 [50.9 kB]
# Get:265 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepoxy0 amd64 1.5.10-1 [237 kB]
# Get:266 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevent-2.1-7 amd64 2.1.12-stable-1build3 [148 kB]
# Get:267 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfaad2 amd64 2.10.0-2 [197 kB]
# Get:268 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libffi7 amd64 3.3-5ubuntu1 [19.9 kB]
# Get:269 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:270 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5427 kB]
# Get:271 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:272 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:273 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfreeaptx0 amd64 0.1.1-1 [12.9 kB]
# Get:274 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgraphene-1.0-0 amd64 1.10.8-1 [48.2 kB]
# Get:275 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgssdp-1.2-0 amd64 1.4.0.1-2build1 [48.9 kB]
# Get:276 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl1 amd64 1.4.0-1 [28.6 kB]
# Get:277 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.4 [204 kB]
# Get:278 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7192 B]
# Get:279 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2.2 [239 kB]
# Get:280 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2.2 [3053 kB]
# Get:281 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-4-common all 4.6.9+ds-0ubuntu0.22.04.2 [662 kB]
# Get:282 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-4-1 amd64 4.6.9+ds-0ubuntu0.22.04.2 [2866 kB]
# Get:283 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgupnp-1.2-1 amd64 1.4.3-1 [93.3 kB]
# Get:284 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgupnp-igd-1.0-4 amd64 1.2.0-1build1 [16.8 kB]
# Get:285 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.2 [5890 B]
# Get:286 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:287 http://archive.ubuntu.com/ubuntu jammy/main amd64 libice6 amd64 2:1.0.10-1build2 [42.6 kB]
# Get:288 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libilmbase25 amd64 2.5.7-2 [175 kB]
# Get:289 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-common all 1.6.6-1build1 [4432 B]
# Get:290 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-0 amd64 1.6.6-1build1 [69.9 kB]
# Get:291 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkate1 amd64 0.4.1-11build1 [39.4 kB]
# Get:292 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldacbt-enc2 amd64 2.0.2.3+git20200429+ed310a0-4 [24.6 kB]
# Get:293 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libltc11 amd64 1.3.1-1 [12.3 kB]
# Get:294 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:295 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmanette-0.2-0 amd64 0.2.6-3build1 [30.4 kB]
# Get:296 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmjpegutils-2.1-0 amd64 1:2.1.0+debian-6build1 [24.1 kB]
# Get:297 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodplug1 amd64 1:0.8.9.0-3 [153 kB]
# Get:298 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpcdec6 amd64 2:0.1~r495-2 [32.4 kB]
# Get:299 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpeg2encpp-2.1-0 amd64 1:2.1.0+debian-6build1 [69.4 kB]
# Get:300 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmplex2-2.1-0 amd64 1:2.1.0+debian-6build1 [44.4 kB]
# Get:301 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnice10 amd64 0.1.18-2 [156 kB]
# Get:302 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnotify4 amd64 0.7.9-3ubuntu5.22.04.1 [20.3 kB]
# Get:303 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnspr4 amd64 2:4.35-0ubuntu0.22.04.1 [119 kB]
# Get:304 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnss3 amd64 2:3.98-0ubuntu0.22.04.2 [1347 kB]
# Get:305 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenexr25 amd64 2.5.7-1 [780 kB]
# Get:306 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenh264-6 amd64 2.2.0+dfsg-2 [407 kB]
# Get:307 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenni2-0 amd64 2.2.0.33+dfsg-15 [389 kB]
# Get:308 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqrencode4 amd64 4.1.1-1 [24.0 kB]
# Get:309 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-common all 0.20.5-2 [4278 B]
# Get:310 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-1-0 amd64 0.20.5-2 [124 kB]
# Get:311 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsm6 amd64 2:1.2.3-1build2 [16.7 kB]
# Get:312 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsoundtouch1 amd64 2.3.1+ds1-1 [38.3 kB]
# Get:313 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-common all 3.0.7-0ubuntu1 [62.1 kB]
# Get:314 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-0 amd64 3.0.7-0ubuntu1 [278 kB]
# Get:315 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:316 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrtp2-1 amd64 2.4.2-2 [40.7 kB]
# Get:317 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwebpdemux2 amd64 1.2.2-2ubuntu0.22.04.2 [9964 B]
# Get:318 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu5 [291 kB]
# Get:319 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi2 amd64 0.4.3-1 [59.9 kB]
# Get:320 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:321 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxt6 amd64 1:1.2.1-1 [177 kB]
# Get:322 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu6 amd64 2:1.1.3-3 [49.6 kB]
# Get:323 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxpm4 amd64 1:3.5.12-1ubuntu0.22.04.2 [36.7 kB]
# Get:324 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxaw7 amd64 2:1.0.14-1 [191 kB]
# Get:325 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:326 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:327 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxslt1.1 amd64 1.1.34-4ubuntu0.22.04.4 [165 kB]
# Get:328 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:329 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzbar0 amd64 0.23.92-4build2 [121 kB]
# Get:330 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzxingcore1 amd64 1.2.0-1 [619 kB]
# Get:331 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:332 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:333 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:334 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:335 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Get:336 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.15 [29.5 kB]
# Get:337 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.15 [866 kB]
# Get:338 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdca0 amd64 0.0.7-2 [88.2 kB]
# Get:339 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgstreamer-plugins-bad1.0-0 amd64 1.20.3-0ubuntu1.1 [489 kB]
# Get:340 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsbc1 amd64 1.5-3build2 [34.4 kB]
# Get:341 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-aacenc0 amd64 0.1.3-2 [69.4 kB]
# Get:342 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-amrwbenc0 amd64 0.1.3-2 [68.2 kB]
# Get:343 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-plugins-bad amd64 1.20.3-0ubuntu1.1 [2602 kB]
# ...
# Setting up libopengl0:amd64 (1.4.0-1) ...
# Setting up libflac8:amd64 (1.3.3-2ubuntu0.2) ...
# Setting up libsnappy1v5:amd64 (1.1.8-1build3) ...
# Setting up libvo-aacenc0:amd64 (0.1.3-2) ...
# Setting up libcap2-bin (1:2.44-1ubuntu0.22.04.2) ...
# Setting up libopenexr25:amd64 (2.5.7-1) ...
# Setting up libxcb-present0:amd64 (1.14-3ubuntu3) ...
# Setting up libdconf1:amd64 (0.40.0-3) ...
# Setting up libasound2-data (1.2.6.1-1ubuntu1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libblas3:amd64 (3.10.0-2ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/blas/libblas.so.3 to provide /usr/lib/x86_64-linux-gnu/libblas.so.3 (libblas.so.3-x86_64-linux-gnu) in auto mode
# Setting up libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Setting up libgles2:amd64 (1.4.0-1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up libdvdread8:amd64 (6.1.2-1) ...
# Setting up emacsen-common (3.0.4) ...
# Setting up libslang2:amd64 (2.3.2-5build4) ...
# Setting up libva2:amd64 (2.14.0-1) ...
# Setting up libx11-data (2:1.7.5-1ubuntu0.3) ...
# Setting up libepoxy0:amd64 (1.5.10-1) ...
# Setting up libnspr4:amd64 (2:4.35-0ubuntu0.22.04.1) ...
# Setting up libxcb-sync1:amd64 (1.14-3ubuntu3) ...
# Setting up libavahi-common-data:amd64 (0.8-5ubuntu5.2) ...
# Setting up libx264-163:amd64 (2:0.163.3060+git5db6aa6-2build1) ...
# Setting up libdbus-1-3:amd64 (1.12.20-2ubuntu4.1) ...
# Setting up dbus (1.12.20-2ubuntu4.1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libfribidi0:amd64 (1.0.8-2ubuntu3.1) ...
# Setting up libopus0:amd64 (1.3.1-0.1build2) ...
# Setting up libfaad2:amd64 (2.10.0-2) ...
# Setting up libpng16-16:amd64 (1.6.37-3build5) ...
# Setting up libvorbis0a:amd64 (1.3.7-1build2) ...
# Setting up libevent-2.1-7:amd64 (2.1.12-stable-1build3) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2ubuntu0.1) ...
# Setting up libabsl20210324:amd64 (0~20210324.2-2ubuntu0.2) ...
# Setting up ucf (3.0043) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libsensors5:amd64 (1:3.6.0-7ubuntu1) ...
# Setting up libjpeg-turbo8:amd64 (2.1.2-0ubuntu1) ...
# Setting up libglapi-mesa:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libgfortran5:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libltc11:amd64 (1.3.1-1) ...
# Setting up libsoup2.4-common (2.74.2-3ubuntu0.5) ...
# Setting up libwebp7:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libxcb-dri2-0:amd64 (1.14-3ubuntu3) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libnuma1:amd64 (2.0.14-3ubuntu2) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libdv4:amd64 (1.0.0-14build1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up ocl-icd-libopencl1:amd64 (2.2.14-3) ...
# Setting up libasyncns0:amd64 (0.8-6build2) ...
# Setting up libwildmidi2:amd64 (0.4.3-1) ...
# Setting up libxshmfence1:amd64 (1.3-1build4) ...
# Setting up libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Setting up libxcb-randr0:amd64 (1.14-3ubuntu3) ...
# Setting up libzxingcore1:amd64 (1.2.0-1) ...
# Setting up libasound2:amd64 (1.2.6.1-1ubuntu1) ...
# Setting up fonts-liberation (1:1.07.4-11) ...
# Setting up libpam-systemd:amd64 (249.11-0ubuntu3.16) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libdca0:amd64 (0.0.7-2) ...
# Setting up libzimg2:amd64 (3.0.3+ds1-1) ...
# Setting up libopenjp2-7:amd64 (2.4.0-6ubuntu0.3) ...
# Setting up libx11-6:amd64 (2:1.7.5-1ubuntu0.3) ...
# Setting up libopenal-data (1:1.19.1-2build3) ...
# Setting up libthai-data (0.1.29-1build1) ...
# Setting up libjson-glib-1.0-common (1.6.6-1build1) ...
# Setting up libvpx7:amd64 (1.11.0-2ubuntu2.4) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libwayland-egl1:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.25-1ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up glib-networking-common (2.72.0-1) ...
# Setting up libdav1d5:amd64 (0.9.2-1) ...
# Setting up libmfx1:amd64 (22.3.0-1) ...
# Setting up libde265-0:amd64 (1.0.8-1ubuntu0.3) ...
# Setting up libsamplerate0:amd64 (0.2.2-1build1) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up libwebpmux3:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libdrm-common (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libelf1:amd64 (0.186-1ubuntu0.1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libxml2:amd64 (2.9.13+dfsg-1ubuntu0.7) ...
# Setting up libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up iso-codes (4.9.0-1) ...
# Setting up libxmuu1:amd64 (2:1.1.3-3) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libzvbi-common (0.2.35-19) ...
# Setting up libsecret-common (0.20.5-2) ...
# Setting up libmp3lame0:amd64 (3.100-3build2) ...
# Setting up libgraphene-1.0-0:amd64 (1.10.8-1) ...
# Setting up libvorbisenc2:amd64 (1.3.7-1build2) ...
# Setting up libdvdnav4:amd64 (6.1.1-1) ...
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up libaa1:amd64 (1.4p5-50build1) ...
# Setting up libiec61883-0:amd64 (1.2.0-4build3) ...
# Setting up libserd-0-0:amd64 (0.30.10-2) ...
# Setting up libxkbcommon0:amd64 (1.4.0-1) ...
# Setting up libwayland-client0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libjpeg8:amd64 (8c-2ubuntu10) ...
# Setting up libavc1394-0:amd64 (0.5.4-5build2) ...
# Setting up libxcb-dri3-0:amd64 (1.14-3ubuntu3) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up libzvbi0:amd64 (0.2.35-19) ...
# Setting up libx11-xcb1:amd64 (2:1.7.5-1ubuntu0.3) ...
# Setting up libice6:amd64 (2:1.0.10-1build2) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up libdw1:amd64 (0.186-1ubuntu0.1) ...
# Setting up liblapack3:amd64 (3.10.0-2ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3 to provide /usr/lib/x86_64-linux-gnu/liblapack.so.3 (liblapack.so.3-x86_64-linux-gnu) in auto mode
# Setting up libxdamage1:amd64 (1:1.1.5-2build2) ...
# Setting up libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Setting up libzmq5:amd64 (4.3.4-2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.2ubuntu4) ...
# Setting up libxpm4:amd64 (1:3.5.12-1ubuntu0.22.04.2) ...
# Setting up libxrender1:amd64 (1:0.9.10-1build4) ...
# Setting up dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libcdio-cdda2:amd64 (10.2+2.0.0-1build3) ...
# Setting up fontconfig-config (2.13.1-4.2ubuntu5) ...
# Setting up libcdio-paranoia2:amd64 (10.2+2.0.0-1build3) ...
# Setting up libwebpdemux2:amd64 (1.2.2-2ubuntu0.22.04.2) ...
# Setting up libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Setting up libavahi-common3:amd64 (0.8-5ubuntu5.2) ...
# Setting up libxext6:amd64 (2:1.3.4-1build1) ...
# Setting up libnss3:amd64 (2:3.98-0ubuntu0.22.04.2) ...
# Setting up libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1build3) ...
# Setting up libthai0:amd64 (0.1.29-1build1) ...
# Setting up libvorbisfile3:amd64 (1.3.7-1build2) ...
# Setting up dbus-user-session (1.12.20-2ubuntu4.1) ...
# Setting up libsecret-1-0:amd64 (0.20.5-2) ...
# Setting up libfreetype6:amd64 (2.11.1+dfsg-1ubuntu0.3) ...
# Setting up libxfixes3:amd64 (1:6.0.0-1) ...
# Setting up libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Setting up libgav1-0:amd64 (0.17.0-1build1) ...
# Setting up shared-mime-info (2.1-2) ...
# Setting up libxinerama1:amd64 (2:1.1.4-3) ...
# Setting up libdc1394-25:amd64 (2.2.6-4) ...
# Setting up libxv1:amd64 (2:1.0.11-1build2) ...
# Setting up libxrandr2:amd64 (2:1.5.2-1build1) ...
# Setting up libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libx265-199:amd64 (3.5-2) ...
# Setting up librubberband2:amd64 (2.0.0-2) ...
# Setting up libsndio7.0:amd64 (1.8.1-1.1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.20~dfsg-1) ...
# Setting up libdrm2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libflite1:amd64 (2.2-3) ...
# Setting up libva-drm2:amd64 (2.14.0-1) ...
# Setting up xauth (1:1.1-1build2) ...
# Setting up libvdpau1:amd64 (1.4-3build2) ...
# Setting up libsord-0-0:amd64 (0.16.8-2) ...
# Setting up libwayland-cursor0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libsratom-0-0:amd64 (0.6.8-1) ...
# Setting up libllvm15:amd64 (1:15.0.7-0ubuntu0.22.04.3) ...
# Setting up libv4lconvert0:amd64 (1.22.1-2build1) ...
# Setting up libxslt1.1:amd64 (1.1.34-4ubuntu0.22.04.4) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libdecor-0-0:amd64 (0.1.0-3build1) ...
# Setting up libharfbuzz0b:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libtiff5:amd64 (4.3.0-6ubuntu0.10) ...
# Setting up libxss1:amd64 (1:1.2.3-1build2) ...
# Setting up libfontconfig1:amd64 (2.13.1-4.2ubuntu5) ...
# Setting up libsndfile1:amd64 (1.0.31-2ubuntu0.2) ...
# Setting up libbluray2:amd64 (1:1.3.1-1) ...
# Setting up libva-x11-2:amd64 (2.14.0-1) ...
# Setting up libyuv0:amd64 (0.0~git20220104.b91df1a-2) ...
# Setting up libsm6:amd64 (2:1.2.3-1build2) ...
# Setting up liblilv-0-0:amd64 (0.24.12-2) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libopenmpt0:amd64 (0.6.1-1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libavahi-client3:amd64 (0.8-5ubuntu5.2) ...
# Setting up libgstreamer1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# unable to set CAP_SETFCAP effective capability: Operation not permitted
# Setcap failed on gst-ptp-helper, falling back to setuid
# Setting up libdrm-amdgpu1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up fontconfig (2.13.1-4.2ubuntu5) ...
# Regenerating fonts cache... done.
# Setting up libdrm-nouveau2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.2) ...
# Setting up libxi6:amd64 (2:1.8-1build1) ...
# Setting up libgbm1:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libpulse0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Setting up libdrm-radeon1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxcursor1:amd64 (1:1.2.0-2build4) ...
# Setting up libpango-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libsrtp2-1:amd64 (2.4.2-2) ...
# Setting up libdrm-intel1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libgl1-mesa-dri:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.4) ...
# Setting up dconf-service (0.40.0-3) ...
# Setting up libopenal1:amd64 (1:1.19.1-2build3) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libcairo2:amd64 (1.16.0-5ubuntu2) ...
# Setting up libavutil56:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libv4l-0:amd64 (1.22.1-2build1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.3) ...
# Setting up libegl-mesa0:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libass9:amd64 (1:0.15.2-1) ...
# Setting up libpostproc55:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libxt6:amd64 (1:1.2.1-1) ...
# Setting up libcups2:amd64 (2.4.1op1-1ubuntu4.11) ...
# Setting up libavif13:amd64 (0.9.3-3) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu4) ...
# Setting up libegl1:amd64 (1.4.0-1) ...
# Setting up libgdk-pixbuf-2.0-0:amd64 (2.42.8+dfsg-1ubuntu0.3) ...
# Setting up libswscale5:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libcairo-gobject2:amd64 (1.16.0-5ubuntu2) ...
# Setting up libpangoft2-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up libpangocairo-1.0-0:amd64 (1.50.6+ds-2ubuntu1) ...
# Setting up libcairo-script-interpreter2:amd64 (1.16.0-5ubuntu2) ...
# Setting up gtk-update-icon-cache (3.24.33-1ubuntu2.2) ...
# Setting up libxmu6:amd64 (2:1.1.3-3) ...
# Setting up libglx-mesa0:amd64 (23.2.1-1ubuntu3.1~22.04.3) ...
# Setting up libglx0:amd64 (1.4.0-1) ...
# Setting up dconf-gsettings-backend:amd64 (0.40.0-3) ...
# Setting up libsphinxbase3:amd64 (0.8+5prealpha+1-13build1) ...
# Setting up libzbar0:amd64 (0.23.92-4build2) ...
# Setting up libxaw7:amd64 (2:1.0.14-1) ...
# Setting up libswresample3:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up librsvg2-2:amd64 (2.52.5+dfsg-3ubuntu0.2) ...
# Setting up libpocketsphinx3:amd64 (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.4) ...
# Setting up libgl1:amd64 (1.4.0-1) ...
# Setting up libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Setting up libshout3:amd64 (2.4.5-1build3) ...
# Setting up libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libgtk-4-common (4.6.9+ds-0ubuntu0.22.04.2) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2.2) ...
# Setting up libchromaprint1:amd64 (1.5.1-2) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libavformat58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.4) ...
# Setting up libavfilter7:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3ubuntu0.5) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.3) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.15) ...
# Setting up libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Setting up libavdevice58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up ffmpeg (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Setting up libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Setting up libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Setting up libnice10:amd64 (0.1.18-2) ...
# Setting up gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up humanity-icon-theme (0.6.16) ...
# Setting up ubuntu-mono (20.10-0ubuntu2) ...
# Setting up adwaita-icon-theme (41.0-1ubuntu1) ...
# update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up libgtk-4-1:amd64 (4.6.9+ds-0ubuntu0.22.04.2) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2.2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.9) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline

# %%
import asyncio
from playwright.async_api import async_playwright
import json
import nest_asyncio

nest_asyncio.apply()

async def get_page_info(page=None):  
    # GPU 가속 상태 확인
    if page:
        gpu_info = await page.evaluate("""() => {
            const canvas = document.createElement('canvas');
            const gl = canvas.getContext('webgl') || canvas.getContext('experimental-webgl');
            
            if (!gl) {
                return { gpuAccelerated: false, reason: 'WebGL not supported' };
            }
            
            const debugInfo = gl.getExtension('WEBGL_debug_renderer_info');
            const vendor = debugInfo ? gl.getParameter(debugInfo.UNMASKED_VENDOR_WEBGL) : 'Unknown';
            const renderer = debugInfo ? gl.getParameter(debugInfo.UNMASKED_RENDERER_WEBGL) : 'Unknown';
            
            return {
                gpuAccelerated: true,
                vendor: vendor,
                renderer: renderer,
                webglVersion: gl.getParameter(gl.VERSION),
                shadingLanguageVersion: gl.getParameter(gl.SHADING_LANGUAGE_VERSION),
                extensions: gl.getSupportedExtensions()
            };
        }""")
        
        # GPU 정보 저장
        with open('gpu_info.json', 'w') as f:
            json.dump(gpu_info, f, indent=2)
                
        # 추가적인 브라우저 정보
        browser_info = await page.evaluate("""() => {
            return {
                userAgent: navigator.userAgent,
                platform: navigator.platform,
                hardwareConcurrency: navigator.hardwareConcurrency,
                deviceMemory: navigator.deviceMemory || 'Not available'
            };
        }""")
    
        with open('browser_info.json', 'w') as f:
            json.dump(browser_info, f, indent=2)
    
    
        return gpu_info, browser_info
    else:
        raise "No Page Instance"
        return False

    
async def capture_screenshot_with_gpu(url, output_path, enable_gpu=True):
    async with async_playwright() as p:
        # GPU 가속 플래그 설정
        gpu_flags = [
            '--enable-gpu-rasterization',
            '--ignore-gpu-blocklist',
            '--enable-webgl',
            '--use-gl=angle',
            '--use-angle=metal',
        ]

        no_gpu_flags = [
            '--disable-gpu',                   # GPU 하드웨어 가속 비활성화
            '--disable-gpu-compositing',       # GPU 컴포지팅 비활성화
            '--disable-gpu-rasterization',     # GPU 래스터화 비활성화
            '--disable-software-rasterizer',   # 소프트웨어 래스터라이저 비활성화
            '--disable-webgl',                 # WebGL 비활성화
        ]        
        
        # 브라우저 실행
        browser = await p.chromium.launch(
            headless=True,
            args= gpu_flags if enable_gpu else no_gpu_flags,
            chromium_sandbox=False
        )
        
        context = await browser.new_context(
            is_mobile=False,
            has_touch=False,
            # javascript_enabled=True,
            viewport={"width": 1280, "height": 800}
        )
        
        page = await context.new_page()
        
        # 웹사이트 방문
        await page.goto(url)
        await page.screenshot(path=output_path, full_page=True)
        
        # GPU 가속 상태 확인
        gpu_info, browser_info = await get_page_info(page)
        
        
        await browser.close()
        return gpu_info, browser_info

# %%
gpu_info, browser_info = await capture_screenshot_with_gpu("https://webglsamples.org/dynamic-cubemap/dynamic-cubemap.html", "screenshot_1.png")

# %%
gpu_info
# Out:
# {'gpuAccelerated': True,
#  'vendor': 'Google Inc. (Google)',
#  'renderer': 'ANGLE (Google, Vulkan 1.3.0 (SwiftShader Device (Subzero) (0x0000C0DE)), SwiftShader driver)',
#  'webglVersion': 'WebGL 1.0 (OpenGL ES 2.0 Chromium)',
#  'shadingLanguageVersion': 'WebGL GLSL ES 1.0 (OpenGL ES GLSL ES 1.0 Chromium)',
#  'extensions': ['ANGLE_instanced_arrays',
#   'EXT_blend_minmax',
#   'EXT_clip_control',
#   'EXT_color_buffer_half_float',
#   'EXT_depth_clamp',
#   'EXT_float_blend',
#   'EXT_frag_depth',
#   'EXT_polygon_offset_clamp',
#   'EXT_shader_texture_lod',
#   'EXT_texture_compression_bptc',
#   'EXT_texture_compression_rgtc',
#   'EXT_texture_filter_anisotropic',
#   'EXT_texture_mirror_clamp_to_edge',
#   'EXT_sRGB',
#   'OES_element_index_uint',
#   'OES_fbo_render_mipmap',
#   'OES_standard_derivatives',
#   'OES_texture_float',
#   'OES_texture_float_linear',
#   'OES_texture_half_float',
#   'OES_texture_half_float_linear',
#   'OES_vertex_array_object',
#   'WEBGL_color_buffer_float',
#   'WEBGL_compressed_texture_astc',
#   'WEBGL_compressed_texture_etc',
#   'WEBGL_compressed_texture_etc1',
#   'WEBGL_compressed_texture_s3tc',
#   'WEBGL_compressed_texture_s3tc_srgb',
#   'WEBGL_debug_renderer_info',
#   'WEBGL_debug_shaders',
#   'WEBGL_depth_texture',
#   'WEBGL_draw_buffers',
#   'WEBGL_lose_context',
#   'WEBGL_multi_draw',
#   'WEBGL_polygon_mode']}

# %%
browser_info
# Out:
# {'userAgent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) HeadlessChrome/138.0.7204.23 Safari/537.36',
#  'platform': 'Linux x86_64',
#  'hardwareConcurrency': 192,
#  'deviceMemory': 8}
